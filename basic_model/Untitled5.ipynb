# %%
import datetime

# %%
import csv
import urllib2

url = 'http://www.google.com/finance/getprices?p=1d&f=d,h,o,l,c,v&i=300&x=INDEXNIKKEI&q=NI225'
response = urllib2.urlopen(url)
cr = csv.reader(response)

for row in cr:
    print row
# Out:
# ['EXCHANGE%3DINDEXNIKKEI']
# ['MARKET_OPEN_MINUTE=540']
# ['MARKET_CLOSE_MINUTE=900']
# ['INTERVAL=300']
# ['COLUMNS=DATE', 'CLOSE', 'HIGH', 'LOW', 'OPEN', 'VOLUME']
# ['DATA_SESSIONS=[MORNING', '540', '690]', '[AFTERNOON', '750', '900]']
# ['DATA=']
# ['TIMEZONE_OFFSET=540']
# ['a1448582700', '19987.61', '19994.05', '19968.83', '19994.05', '0']
# ['1', '19981.45', '19990.58', '19976.9', '19989.05', '0']
# ['2', '19972.71', '19983.75', '19972.04', '19982.36', '0']
# ['3', '19979.59', '19982.95', '19972.11', '19973.85', '0']
# ['4', '19964.27', '19973.73', '19964.17', '19973.73', '0']
# ['5', '19967.03', '19968.42', '19963.02', '19964.22', '0']
# ['6', '19956.22', '19968.3', '19953.06', '19968.3', '0']
# ['7', '19949.97', '19956.08', '19949.28', '19955.64', '0']
# ['8', '19954.51', '19954.81', '19950.02', '19950.5', '0']
# ['9', '19961.26', '19963.18', '19953.49', '19955.15', '0']
# ['10', '19969.77', '19969.77', '19958.57', '19960.14', '0']
# ...

# %%
l = datetime.datetime.fromtimestamp(1427414700).date

# %%
l()
# Out:
# datetime.date(2015, 3, 27)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5ec5852914cf> in <module>()
# ----> 1 l(y)
#
# NameError: name 'y' is not defined
